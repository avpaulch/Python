# %% [markdown]
# ## Question 1
# **What is Dimensionality Reduction? Why is it important in machine learning?**
#
# Dimensionality Reduction is the process of reducing the number of input variables or features in a dataset while preserving as much relevant information as possible.
#
# **Importance:**
# - Reduces computational cost.
# - Helps mitigate the curse of dimensionality.
# - Improves model performance and visualization.

# %% [markdown]
# ## Question 2
# **Three common dimensionality reduction techniques:**
# 1. **Principal Component Analysis (PCA):** Transforms data into a set of orthogonal components that capture maximum variance.
# 2. **Linear Discriminant Analysis (LDA):** Focuses on maximizing class separability.
# 3. **t-SNE:** Non-linear technique for visualizing high-dimensional data in 2D or 3D.

# %% [markdown]
# ## Question 3
# **Clustering in Unsupervised Learning:**
# Clustering is the process of grouping similar data points together without predefined labels.
#
# **Popular algorithms:**
# - K-Means
# - Hierarchical Clustering
# - DBSCAN

# %% [markdown]
# ## Question 4
# **Anomaly Detection:**
# Anomaly detection identifies data points that deviate significantly from the norm.
#
# **Significance:**
# - Detect fraud, network intrusions, equipment failures, etc.

# %% [markdown]
# ## Question 5
# **Three types of anomaly detection techniques:**
# 1. **Statistical methods:** Assume normal distribution and detect outliers.
# 2. **Machine learning models:** Isolation Forest, One-Class SVM.
# 3. **Proximity-based methods:** k-NN based anomaly detection.

# %% [markdown]
# ## Question 6
# **Time Series Analysis:**
# It involves analyzing data points collected or recorded at specific time intervals.
#
# **Key components:**
# - Trend
# - Seasonality

# %% [markdown]
# ## Question 7
# **Difference between seasonality and cyclic behavior:**
# - **Seasonality:** Regular, predictable patterns that repeat over a fixed period (e.g., yearly sales).
# - **Cyclic behavior:** Irregular patterns influenced by economic or other factors without a fixed period.

# %% [markdown]
# ## Question 8
# **Python code for K-means clustering:**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Generate sample data
np.random.seed(42)
X = np.random.rand(100, 2)

# Apply KMeans
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X)
labels = kmeans.labels_
centers = kmeans.cluster_centers_

# Plot clusters
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='red', marker='X', s=200)
plt.title('K-Means Clustering')
plt.show()

# %% [markdown]
# ## Question 9
# **Inheritance in OOP with Python example:**

# %%
class Animal:
    def speak(self):
        return 'This is an animal sound'

class Dog(Animal):
    def speak(self):
        return 'Woof!'

# Test inheritance
animal = Animal()
dog = Dog()
print(animal.speak())
print(dog.speak())
# Out:
# This is an animal sound
# Woof!

# %% [markdown]
# ## Question 10
# **Time series analysis for anomaly detection:**
# By modeling normal patterns in time series data (trend, seasonality), anomalies can be detected when observations deviate significantly from expected behavior. Techniques include ARIMA residual analysis and machine learning-based forecasting.
